# %% [markdown]
# #### Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Parametros

# %%
PATH = 'C:/Users/tinch/coderhouse/template/data/processed/'

# %% [markdown]
# #### Lectura del archivo

# %%
df = pd.read_csv(f'{PATH}dataset_merged.csv')

# %%
df.head(3)
# Out:
#    ID  systolic  relaxation  Cholesterol  triglyceride       HDL       LDL  \
# 0   0  4.750000    3.041667     8.958333      3.416667  3.041667  5.250000
# 1   1  4.958333    2.916667     8.000000      4.791667  1.750000  5.291667
# 2   2  5.750000    3.583333    10.083333      7.583333  2.291667  6.291667
#
#   gender   age  height(cm)  ...       ALT       Gtp  oral  dental caries  \
# 0      F  40.0       155.0  ...  0.791667  1.125000     Y              0
# 1      F  40.0       160.0  ...  0.791667  0.750000     Y              0
# 2      M  55.0       170.0  ...  0.666667  0.916667     Y              0
#
#    tartar  eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# 0       Y        0.043056         0.041667       0.041667        0.041667
# 1       Y        0.005556         0.004167       0.041667        0.041667
# 2       N        0.005556         0.005556       0.041667        0.041667
#
#   target
# 0      0
# 1      0
# 2      1
#
# [3 rows x 27 columns]

# %%
df.tail(3)
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 49997  27351       NaN         NaN          NaN           NaN  1.958333
# 49998  27352       NaN         NaN          NaN           NaN  2.583333
# 49999  27354       NaN         NaN          NaN           NaN  2.750000
#
#             LDL gender   age  height(cm)  ...  ALT       Gtp  oral  \
# 49997  2.208333      M  20.0       165.0  ...  NaN  2.916667     Y
# 49998  4.125000      F  60.0       160.0  ...  NaN  1.041667     Y
# 49999  5.041667      M  45.0       170.0  ...  NaN  2.583333     Y
#
#        dental caries  tartar  eyesight(left)  eyesight(right)  hearing(left)  \
# 49997              0       Y        0.045139         0.045139       0.041667
# 49998              1       Y        0.002778         0.002778       0.041667
# 49999              1       N        0.045139         0.041667       0.041667
#
#        hearing(right) target
# 49997             NaN      1
# 49998             NaN      0
# 49999             NaN      1
#
# [3 rows x 27 columns]

# %%
df.sample(5, random_state=42)
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 33553  41917  6.000000    3.958333        8.375      1.875000  2.500000
# 9427   11817  5.208333    3.125000        8.125      2.916667  3.291667
# 199      260       NaN         NaN          NaN      4.250000  2.333333
# 12447  15517  5.791667    3.416667       10.625      5.750000  2.750000
# 39489  49334  4.375000    2.708333        7.375      4.375000  2.583333
#
#             LDL gender   age  height(cm)  ...       ALT       Gtp  oral  \
# 33553  5.500000      M  55.0       175.0  ...  1.000000  2.416667     Y
# 9427   4.250000      F  40.0       160.0  ...  0.791667  0.375000     Y
# 199    5.458333      F  40.0       150.0  ...  1.250000  0.916667     Y
# 12447  6.708333      F  50.0       155.0  ...  0.958333  0.666667     Y
# 39489  3.916667      F  45.0       150.0  ...  0.583333  0.625000     Y
#
#        dental caries  tartar  eyesight(left)  eyesight(right)  hearing(left)  \
# 33553              1       N        0.041667         0.041667       0.041667
# 9427               0       Y        0.006250         0.004861       0.041667
# 199                0       N        0.005556         0.004861       0.041667
# 12447              0       N        0.043056         0.043056       0.041667
# 39489              0       Y        0.041667         0.001389       0.041667
#
#        hearing(right) target
# 33553        0.041667      0
# 9427         0.041667      0
# 199          0.041667      0
# 12447        0.041667      0
# 39489        0.041667      0
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             49592 non-null  float64
#  2   relaxation           49588 non-null  float64
#  3   Cholesterol          49390 non-null  float64
#  4   triglyceride         49979 non-null  float64
#  5   HDL                  49053 non-null  float64
#  6   LDL                  49053 non-null  float64
#  7   gender               49963 non-null  str
#  8   age                  49523 non-null  float64
#  9   height(cm)           49587 non-null  float64
#  10  weight(kg)           49914 non-null  float64
#  11  waist(cm)            49616 non-null  float64
#  12  fasting blood sugar  49142 non-null  float64
#  13  hemoglobin           49859 non-null  float64
#  14  Urine protein        49841 non-null  float64
#  15  serum creatinine     38941 non-null  float64
#  16  AST                  4248 non-null   float64
#  17  ALT                  49678 non-null  float64
#  18  Gtp                  49937 non-null  float64
#  19  oral                 50000 non-null  str
#  20  dental caries        50000 non-null  int64
#  21  tartar               50000 non-null  str
#  22  eyesight(left)       49298 non-null  float64
#  23  eyesight(right)      49524 non-null  float64
#  24  hearing(left)        49888 non-null  float64
#  25  hearing(right)       49779 non-null  float64
#  26  target               50000 non-null  int64
# dtypes: float64(21), int64(3), str(3)
# memory usage: 10.4 MB

# %%
df.isna().sum()/df.shape[0]*100 # porcentaje de valores nulos por columna
# Out:
# ID                      0.000
# systolic                0.816
# relaxation              0.824
# Cholesterol             1.220
# triglyceride            0.042
# HDL                     1.894
# LDL                     1.894
# gender                  0.074
# age                     0.954
# height(cm)              0.826
# weight(kg)              0.172
# waist(cm)               0.768
# fasting blood sugar     1.716
# hemoglobin              0.282
# Urine protein           0.318
# serum creatinine       22.118
# AST                    91.504
# ALT                     0.644
# Gtp                     0.126
# oral                    0.000
# dental caries           0.000
# tartar                  0.000
# eyesight(left)          1.404
# eyesight(right)         0.952
# hearing(left)           0.224
# hearing(right)          0.442
# target                  0.000
# dtype: float64

# %%
df.shape
# Out:
# (50000, 27)

# %%
df = df.drop(columns=["AST"])

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df.gender.unique()
# Out:
# <ArrowStringArray>
# ['F', 'M', nan]
# Length: 3, dtype: str

# %%
random_gender = np.random.choice(["F","M"], size=df["gender"].isnull().sum())

# %%
random_gender
# Out:
# array(['F', 'M', 'F', 'F', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M',
#        'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'F',
#        'F', 'F', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M'], dtype='<U1')

# %%
df.loc[df["gender"].isnull(),"gender"] = random_gender

# %%
df.isna().sum()/df.shape[0]*100 # porcentaje de valores nulos por columna
# Out:
# ID                     0.0
# systolic               0.0
# relaxation             0.0
# Cholesterol            0.0
# triglyceride           0.0
# HDL                    0.0
# LDL                    0.0
# gender                 0.0
# age                    0.0
# height(cm)             0.0
# weight(kg)             0.0
# waist(cm)              0.0
# fasting blood sugar    0.0
# hemoglobin             0.0
# Urine protein          0.0
# serum creatinine       0.0
# ALT                    0.0
# Gtp                    0.0
# oral                   0.0
# dental caries          0.0
# tartar                 0.0
# eyesight(left)         0.0
# eyesight(right)        0.0
# hearing(left)          0.0
# hearing(right)         0.0
# target                 0.0
# dtype: float64

# %%
df.ID.nunique()
# Out:
# 50000

# %%
df.duplicated().sum() # sacar el ID
# Out:
# np.int64(0)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)
